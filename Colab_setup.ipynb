# %% [markdown]
# ### Step 1: Mount the Google Drive
#
# Remember to use GPU runtime before mounting your Google Drive. (Runtime --> Change runtime type).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ### Step 2: Open the project directory
#
# Replace `Your_Dir` with your own path.

# %%
# cd Your_Dir/emg2qwerty
# %cd /content/drive/MyDrive/NeuralNetFinalProject/NeuralNetFinalProject
# !ls

# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, Colab will require you to restart the session.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 4: Start your experiments!
#
# - Remember to download and copy the dataset to this directory: `Your_Dir/emg2qwerty/data`.
# - You may now start your experiments with any scripts! Below are examples of single-user training and testing (greedy decoding).
# - **There are two ways to track the logs:**
#   - 1. Keep `--multirun`, and the logs will not be printed here, but they will be saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/submitit_logs/`.
#   - 2. Comment out `--multirun` and the logs will be printed in this notebook, but they will not be saved.

# %% [markdown]
# #### Training
#
# - The checkpoints are saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/checkpoints/`.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1 \
  # --multirun
# Out:
# [2026-03-06 13:46:07,986][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.CNNTCNBiLSTMCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   cnn_channels: 256
#   cnn_kernel: 5
#   tcn_channels:
#   - 256
#   - 256
#   - 256
#   - 256
#   tcn_kernel_width: 3
#   lstm_hidden: 256
#   lstm_layers: 2
#   dropout: 0.1
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
#   batch_size: ${batch_size}
#   num_workers: ${num_workers}
#   train_sessions: ${dataset.train}
#   val_sessions: ${dataset.val}
#   test_sessions: ${dataset.test}
#   train_transform:
#     _target_: emg2qwerty.transforms.Compose
#     transforms: ${transforms.train}
#   val_transform:
#     _target_: emg2qwerty.transforms.Compose
#     transforms: ${transforms.val}
#   test_transform:
#     _target_: emg2qwerty.transforms.Compose
#     transforms: ${transforms.test}
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.0003
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 150
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
# - _target_: pytorch_lightning.callbacks.EarlyStopping
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   patience: 6
#   min_delta: 0.1
#   verbose: true
#
# Global seed set to 1501
# [2026-03-06 13:46:07,992][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.CNNTCNBiLSTMCTCModule', 'in_features': 528, 'mlp_features': [384], 'cnn_channels': 256, 'cnn_kernel': 5, 'tcn_channels': [256, 256, 256, 256], 'tcn_kernel_width': 3, 'lstm_hidden': 256, 'lstm_layers': 2, 'dropout': 0.1}
# [2026-03-06 13:46:08,183][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200], 'batch_size': '${batch_size}', 'num_workers': '${num_workers}', 'train_sessions': '${dataset.train}', 'val_sessions': '${dataset.val}', 'test_sessions': '${dataset.test}', 'train_transform': {'_target_': 'emg2qwerty.transforms.Compose', 'transforms': '${transforms.train}'}, 'val_transform': {'_target_': 'emg2qwerty.transforms.Compose', 'transforms': '${transforms.val}'}, 'test_transform': {'_target_': 'emg2qwerty.transforms.Compose', 'transforms': '${transforms.test}'}}
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /Users/nkalluri/Desktop/NeuralNet_FinalProject/NeuralNetFinalProject/logs/2026-03-06/13-46-07/lightning_logs
# /Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# /Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name       | Type       | Params
# ------------------------------------------
# 0 | frontend   | Sequential | 406 K
# 1 | cnn        | Sequential | 1.3 M
# 2 | tcn        | TCNEncoder | 1.6 M
# 3 | bilstm     | LSTM       | 2.6 M
# 4 | classifier | Sequential | 50.8 K
# 5 | ctc_loss   | CTCLoss    | 0
# 6 | metrics    | ModuleDict | 0
# ------------------------------------------
# 6.0 M     Trainable params
# 0         Non-trainable params
# 6.0 M     Total params
# 23.892    Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s]^C
# Traceback (most recent call last):
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/utils.py", line 458, in <lambda>
#     lambda: hydra.run(
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/hydra.py", line 132, in run
#     _ = ret.return_value
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/core/utils.py", line 260, in return_value
#     raise self._return_value
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/core/utils.py", line 186, in run_job
#     ret.return_value = task_function(task_cfg)
#   File "/Users/nkalluri/Desktop/NeuralNet_FinalProject/NeuralNetFinalProject/emg2qwerty/train.py", line 110, in main
#     module = module.load_from_checkpoint(
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/pytorch_lightning/core/saving.py", line 137, in load_from_checkpoint
#     return _load_from_checkpoint(
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/pytorch_lightning/core/saving.py", line 158, in _load_from_checkpoint
#     checkpoint = pl_load(checkpoint_path, map_location=map_location)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/lightning_lite/utilities/cloud_io.py", line 47, in _load
#     with fs.open(path_or_url, "rb") as f:
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/fsspec/spec.py", line 1293, in open
#     f = self._open(
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/fsspec/implementations/local.py", line 197, in _open
#     return LocalFileOpener(path, mode, fs=self, **kwargs)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/fsspec/implementations/local.py", line 322, in __init__
#     self._open()
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/fsspec/implementations/local.py", line 327, in _open
#     self.f = open(self.path, mode=self.mode)
# IsADirectoryError: [Errno 21] Is a directory: '/Users/nkalluri/Desktop/NeuralNet_FinalProject/NeuralNetFinalProject/'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/nkalluri/Desktop/NeuralNet_FinalProject/NeuralNetFinalProject/emg2qwerty/train.py", line 129, in <module>
#     main()
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/main.py", line 94, in decorated_main
#     _run_hydra(
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/utils.py", line 394, in _run_hydra
#     _run_app(
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/utils.py", line 457, in _run_app
#     run_and_report(
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/utils.py", line 260, in run_and_report
#     mdl = inspect.getmodule(frame)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/inspect.py", line 875, in getmodule
#     f = getabsfile(module)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/inspect.py", line 844, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/inspect.py", line 826, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Exception ignored in atexit callback: <function _exit_function at 0x1137eff40>
# Traceback (most recent call last):
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/multiprocessing/util.py", line 357, in _exit_function
#     p.join()
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/multiprocessing/popen_fork.py", line 43, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/multiprocessing/popen_fork.py", line 27, in poll
#     pid, sts = os.waitpid(self.pid, flag)
#   File "/Users/nkalluri/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 44878) is killed by signal: Interrupt: 2.

# %% [markdown]
# #### Testing:
#
# - Replace `Your_Path_to_Checkpoint` with your checkpoint path.

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="Your_Path_to_Checkpoint" \
  train=False trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  # --multirun
